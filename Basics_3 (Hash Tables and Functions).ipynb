# %%
# Hash table and map

# %%
# There are two ways to create a dict
my_dict = {"nivi":"001","jacq":"fer","AI":"ML"}
print(my_dict)
type(my_dict)
# Out:
# {'nivi': '001', 'jacq': 'fer', 'AI': 'ML'}
# dict

# %%
new_dict = dict(nivi='001',jacq='002')
print(new_dict)
type(new_dict)
# Out:
# {'nivi': '001', 'jacq': '002'}
# dict

# %%
# Nested Dict
# Which is called dict into another dict values

# %%
emp = {"Details":{"Adam":{"id":"007","des":"Ds","Sal":"10000"},"Eva":{"id":"Henz","des":"Da","Sal":"7000"}}}
print(emp)
# Out:
# {'Details': {'Adam': {'id': '007', 'des': 'Ds', 'Sal': '10000'}, 'Eva': {'id': 'Henz', 'des': 'Da', 'Sal': '7000'}}}

# %%
# Hashing Tables
# Accessing Values

# %%
# Accessing the Item using key values
emp['Details']
# Out:
# {'Adam': {'id': '007', 'des': 'Ds', 'Sal': '10000'},
#  'Eva': {'id': 'Henz', 'des': 'Da', 'Sal': '7000'}}

# %%
my_dict['nivi']
# Out:
# '001'

# %%
print(emp.values())
# Out:
# dict_values([{'Adam': {'id': '007', 'des': 'Ds', 'Sal': '10000'}, 'Eva': {'id': 'Henz', 'des': 'Da', 'Sal': '7000'}}])

# %%
print(emp.keys())
# Out:
# dict_keys(['Details'])

# %%
print(my_dict.keys())
# Out:
# dict_keys(['nivi', 'jacq', 'AI'])

# %%
print(my_dict.values())
# Out:
# dict_values(['001', 'fer', 'ML'])

# %%
# print the elements using loops

# %%
for i in my_dict:
    print(i)
# Out:
# nivi
# jacq
# AI

# %%
for i in my_dict.values():
    print(i)
# Out:
# 001
# fer
# ML

# %%
# Item func() get one or more values from dict

# %%
for i,j in my_dict.items():
    print(i,j)
# Out:
# nivi 001
# jacq fer
# AI ML

# %%
for n,m in emp['Details'].items():
    print(n,m)
# Out:
# Adam {'id': '007', 'des': 'Ds', 'Sal': '10000'}
# Eva {'id': 'Henz', 'des': 'Da', 'Sal': '7000'}

# %%
emp['id'] = '077'

# %%
for n,m in emp['Details'].items():
    print(n,m)
# Out:
# Adam {'id': '007', 'des': 'Ds', 'Sal': '10000'}
# Eva {'id': 'Henz', 'des': 'Da', 'Sal': '7000'}

# %%
# Updating Values
print(my_dict)
# Out:
# {'nivi': '001', 'jacq': 'fer', 'AI': 'ML'}

# %%
my_dict['nivi'] = '007'

# %%
print(my_dict)
# Out:
# {'nivi': '007', 'jacq': 'fer', 'AI': 'ML'}

# %%
my_dict['Chris'] = '005'
my_dict['ML'] = 'Deep Learning'

# %%
print(my_dict)
# Out:
# {'nivi': '007', 'jacq': 'fer', 'AI': 'ML', 'Chris': '005', 'ML': 'Deep Learning'}

# %%
#Deleting Values

# %%
 my_dict.pop('Chris')
# Out:
# '005'

# %%
print(my_dict)
# Out:
# {'nivi': '007', 'jacq': 'fer', 'AI': 'ML', 'ML': 'Deep Learning'}

# %%
my_dict.popitem()
# Out:
# ('ML', 'Deep Learning')

# %%
# Delete the values the last one
print(my_dict)
# Out:
# {'nivi': '007', 'jacq': 'fer', 'AI': 'ML'}

# %%
my_dict.pop('nivi','jacq')
# Out:
# '007'

# %%
print(my_dict)
# Out:
# {'jacq': 'fer', 'AI': 'ML'}

# %%
# Dict to Data frame conversion

# %%
import pandas as pd

# %%
df = pd.DataFrame(emp['Details'])
print(df)
# Out:
#       Adam   Eva
# Sal  10000  7000
# des     Ds    Da
# id     007  Henz
