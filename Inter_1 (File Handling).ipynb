# %% [markdown]
# # File Handling

# %%
# Read Files
import os

# %%
f = open("C:/Users/Nivitus parker/AI.txt","r")
f.read()
# Out:
# 'I Love AI'

# %%
f = open("C:/Users/Nivitus parker/AI.txt","r")
print(f.read())
f.close()
# Out:
# I Love AI

# %%
# The value is specifically says number chars into the sentences
f = open("C:/Users/Nivitus parker/AI.txt","r")
print(f.read(5))
f.close()
# Out:
# I Lov

# %%
# Readlines() used to read the multiple rows
f = open("C:/Users/Nivitus parker/DL.txt","r")
print(f.readlines())
f.close()
# Out:
# ['Hello World!\n', 'I wanna become a Data Scientist\n', 'I Love Deep Learning\n']

# %%
# Using Loops into the files to printing
f = open("C:/Users/Nivitus parker/DL.txt","r")
for line in f:
    print(f.readlines())
f.close()
# Out:
# ['I wanna become a Data Scientist\n', 'I Love Deep Learning\n']

# %%
# Writing Files
w = open("C:/Users/Nivitus parker/write.txt","w")
w.write("Hello World! \n")
w.write("Machine Learning")
w.close()

# %%
# Creating new file
# We can't do create a new file name which is name file is already exists

# %%
# Creating new file
w = open("C:/Users/Nivitus parker/ML.txt","x")
w.write("Hello World!")
w.close()

# %%
# We have done created the new file with in a name of ML

# %%
# Deleteing the files and folders

# %%
import os
# os.remove("foldername.txt")

# %%
# if os.path.exists("foldername.txt"):
   # os.remove("foldername.txt")
# else:
   # print("file dosen't exists")

# %%
# Deleting Folder

# %%
# import os
# os.rmdir("Foldername.txt")
