# %%
#Arithmatic Operators
a = 5
b = 10

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# -5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 0.5

# %%
a ** b
# Out:
# 9765625

# %%
a // b
# Out:
# 0

# %%
a % b
# Out:
# 5

# %%
# Assignment Operators

# %%
a += 5 # a = a + 5

# %%
a
# Out:
# 10

# %%
a *= 5 # Now a value is 10

# %%
a
# Out:
# 50

# %%
c = 5

# %%
c **= 5

# %%
c
# Out:
# 3125

# %%
# Comparrision

# %%
a = 6
b = 6

# %%
com = a == b

# %%
com
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
com = a <= b
com
# Out:
# True

# %%
# Conditional Oper

# %%
if a == b:
    print("equal")
elif a > b:
    print("Greater")
else:
    print("smaller")
# Out:
# equal

# %%
# Logical Operators
# AND
# OR
# NOT

# %%
m = 5
n = 7
not(m < 7)
# Out:
# False

# %%
rt = (m + n == n + m and 10 + 2 == 2 + 10)
rt
# Out:
# True

# %%
rt = (m + n == n + m and 10 + 2 == 2 + 11)
rt
# Out:
# False

# %%
rt = (m + n == n + m or 10 + 2 == 2 + 1)
rt
# Out:
# True

# %%
# Identity Opreator
# is
# is not

# %%
x = item1
x is item1
# Out:
# True

# %%
item1 = [10,11,12,13]
item2 = [10,11,12,13]
item1 is item2
# Out:
# False

# %%
# Even Though we have same name of the values and also same number values two items are different

# %%
item1 is not item2
# Out:
# True

# %%
# both items are different even though twos are same in any conditions

# %%
# Membership Operators
# in
# not in
# It's works based on Member of the particular list or container and so on

# %%
item1 in item2
# Out:
# False

# %%
11 in item2
# Out:
# True

# %%
'banana' in item1
# Out:
# False

# %%
10 not in item1
# Out:
# False

# %%
10 in item1
# Out:
# True

# %%
'Apple' not in item1
# Out:
# True

# %%
# Bitwise Operators || it's based binary number and other number systemz

# %%
10 & 12
# Out:
# 8

# %%
# Here 10 is represented by the it's binary digit 10 = 1010 and 12 = 1100, 
# If both number is one it gives one 
# if anyone is 0 it's gives 0
# 1010 - 10
# 1100 - 12
# 1000 - 8 so the answer is 8

# %%
10 | 12
# Out:
# 14

# %%
# | it's a OR Operator
# 1010 - 10
# 1100 - 12
# 1111 - 14

# %%
10 >> 2
# Out:
# 2

# %%
# 10 - 1010 Shfit the two digits from the right side.

# %%
10 >> 3
# Out:
# 1

# %%
# 10 - 1010 Shfit the three digits from the right side.

# %%
10 << 2
# Out:
# 40
